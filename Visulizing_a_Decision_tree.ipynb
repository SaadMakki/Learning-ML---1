# %% [markdown]
# # Goals
# 1. Import a dataset
# 2. Train a Classifier
# 3. Predict labe for new flower
# 4. Visualize the Tree

# %% [markdown]
# ### Importing a Dataset
# for this i am gonna use the built in dataset with sk-learn.

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
print(iris.data[0])
# Out:
# [5.1 3.5 1.4 0.2]

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
for i in range(len(iris.target)):
    print (f"Example{i} : Label{iris.target[i]}, Feature{iris.data[i]}")
# Out:
# Example0 : Label0, Feature[5.1 3.5 1.4 0.2]
# Example1 : Label0, Feature[4.9 3.  1.4 0.2]
# Example2 : Label0, Feature[4.7 3.2 1.3 0.2]
# Example3 : Label0, Feature[4.6 3.1 1.5 0.2]
# Example4 : Label0, Feature[5.  3.6 1.4 0.2]
# Example5 : Label0, Feature[5.4 3.9 1.7 0.4]
# Example6 : Label0, Feature[4.6 3.4 1.4 0.3]
# Example7 : Label0, Feature[5.  3.4 1.5 0.2]
# Example8 : Label0, Feature[4.4 2.9 1.4 0.2]
# Example9 : Label0, Feature[4.9 3.1 1.5 0.1]
# Example10 : Label0, Feature[5.4 3.7 1.5 0.2]
# Example11 : Label0, Feature[4.8 3.4 1.6 0.2]
# Example12 : Label0, Feature[4.8 3.  1.4 0.1]
# Example13 : Label0, Feature[4.3 3.  1.1 0.1]
# Example14 : Label0, Feature[5.8 4.  1.2 0.2]
# Example15 : Label0, Feature[5.7 4.4 1.5 0.4]
# Example16 : Label0, Feature[5.4 3.9 1.3 0.4]
# Example17 : Label0, Feature[5.1 3.5 1.4 0.3]
# Example18 : Label0, Feature[5.7 3.8 1.7 0.3]
# Example19 : Label0, Feature[5.1 3.8 1.5 0.3]
# Example20 : Label0, Feature[5.4 3.4 1.7 0.2]
# Example21 : Label0, Feature[5.1 3.7 1.5 0.4]
# Example22 : Label0, Feature[4.6 3.6 1.  0.2]
# Example23 : Label0, Feature[5.1 3.3 1.7 0.5]
# Example24 : Label0, Feature[4.8 3.4 1.9 0.2]
# Example25 : Label0, Feature[5.  3.  1.6 0.2]
# Example26 : Label0, Feature[5.  3.4 1.6 0.4]
# Example27 : Label0, Feature[5.2 3.5 1.5 0.2]
# Example28 : Label0, Feature[5.2 3.4 1.4 0.2]
# Example29 : Label0, Feature[4.7 3.2 1.6 0.2]
# Example30 : Label0, Feature[4.8 3.1 1.6 0.2]
# Example31 : Label0, Feature[5.4 3.4 1.5 0.4]
# Example32 : Label0, Feature[5.2 4.1 1.5 0.1]
# Example33 : Label0, Feature[5.5 4.2 1.4 0.2]
# Example34 : Label0, Feature[4.9 3.1 1.5 0.2]
# Example35 : Label0, Feature[5.  3.2 1.2 0.2]
# Example36 : Label0, Feature[5.5 3.5 1.3 0.2]
# Example37 : Label0, Feature[4.9 3.6 1.4 0.1]
# Example38 : Label0, Feature[4.4 3.  1.3 0.2]
# Example39 : Label0, Feature[5.1 3.4 1.5 0.2]
# Example40 : Label0, Feature[5.  3.5 1.3 0.3]
# Example41 : Label0, Feature[4.5 2.3 1.3 0.3]
# Example42 : Label0, Feature[4.4 3.2 1.3 0.2]
# Example43 : Label0, Feature[5.  3.5 1.6 0.6]
# Example44 : Label0, Feature[5.1 3.8 1.9 0.4]
# Example45 : Label0, Feature[4.8 3.  1.4 0.3]
# Example46 : Label0, Feature[5.1 3.8 1.6 0.2]
# Example47 : Label0, Feature[4.6 3.2 1.4 0.2]
# Example48 : Label0, Feature[5.3 3.7 1.5 0.2]
# Example49 : Label0, Feature[5.  3.3 1.4 0.2]
# Example50 : Label1, Feature[7.  3.2 4.7 1.4]
# Example51 : Label1, Feature[6.4 3.2 4.5 1.5]
# Example52 : Label1, Feature[6.9 3.1 4.9 1.5]
# Example53 : Label1, Feature[5.5 2.3 4.  1.3]
# Example54 : Label1, Feature[6.5 2.8 4.6 1.5]
# Example55 : Label1, Feature[5.7 2.8 4.5 1.3]
# Example56 : Label1, Feature[6.3 3.3 4.7 1.6]
# Example57 : Label1, Feature[4.9 2.4 3.3 1. ]
# Example58 : Label1, Feature[6.6 2.9 4.6 1.3]
# Example59 : Label1, Feature[5.2 2.7 3.9 1.4]
# Example60 : Label1, Feature[5.  2.  3.5 1. ]
# Example61 : Label1, Feature[5.9 3.  4.2 1.5]
# Example62 : Label1, Feature[6.  2.2 4.  1. ]
# Example63 : Label1, Feature[6.1 2.9 4.7 1.4]
# Example64 : Label1, Feature[5.6 2.9 3.6 1.3]
# Example65 : Label1, Feature[6.7 3.1 4.4 1.4]
# Example66 : Label1, Feature[5.6 3.  4.5 1.5]
# Example67 : Label1, Feature[5.8 2.7 4.1 1. ]
# Example68 : Label1, Feature[6.2 2.2 4.5 1.5]
# Example69 : Label1, Feature[5.6 2.5 3.9 1.1]
# Example70 : Label1, Feature[5.9 3.2 4.8 1.8]
# Example71 : Label1, Feature[6.1 2.8 4.  1.3]
# Example72 : Label1, Feature[6.3 2.5 4.9 1.5]
# Example73 : Label1, Feature[6.1 2.8 4.7 1.2]
# Example74 : Label1, Feature[6.4 2.9 4.3 1.3]
# Example75 : Label1, Feature[6.6 3.  4.4 1.4]
# Example76 : Label1, Feature[6.8 2.8 4.8 1.4]
# Example77 : Label1, Feature[6.7 3.  5.  1.7]
# Example78 : Label1, Feature[6.  2.9 4.5 1.5]
# Example79 : Label1, Feature[5.7 2.6 3.5 1. ]
# Example80 : Label1, Feature[5.5 2.4 3.8 1.1]
# Example81 : Label1, Feature[5.5 2.4 3.7 1. ]
# Example82 : Label1, Feature[5.8 2.7 3.9 1.2]
# Example83 : Label1, Feature[6.  2.7 5.1 1.6]
# Example84 : Label1, Feature[5.4 3.  4.5 1.5]
# Example85 : Label1, Feature[6.  3.4 4.5 1.6]
# Example86 : Label1, Feature[6.7 3.1 4.7 1.5]
# Example87 : Label1, Feature[6.3 2.3 4.4 1.3]
# Example88 : Label1, Feature[5.6 3.  4.1 1.3]
# Example89 : Label1, Feature[5.5 2.5 4.  1.3]
# Example90 : Label1, Feature[5.5 2.6 4.4 1.2]
# Example91 : Label1, Feature[6.1 3.  4.6 1.4]
# Example92 : Label1, Feature[5.8 2.6 4.  1.2]
# Example93 : Label1, Feature[5.  2.3 3.3 1. ]
# Example94 : Label1, Feature[5.6 2.7 4.2 1.3]
# Example95 : Label1, Feature[5.7 3.  4.2 1.2]
# Example96 : Label1, Feature[5.7 2.9 4.2 1.3]
# Example97 : Label1, Feature[6.2 2.9 4.3 1.3]
# Example98 : Label1, Feature[5.1 2.5 3.  1.1]
# Example99 : Label1, Feature[5.7 2.8 4.1 1.3]
# Example100 : Label2, Feature[6.3 3.3 6.  2.5]
# Example101 : Label2, Feature[5.8 2.7 5.1 1.9]
# Example102 : Label2, Feature[7.1 3.  5.9 2.1]
# Example103 : Label2, Feature[6.3 2.9 5.6 1.8]
# Example104 : Label2, Feature[6.5 3.  5.8 2.2]
# Example105 : Label2, Feature[7.6 3.  6.6 2.1]
# Example106 : Label2, Feature[4.9 2.5 4.5 1.7]
# Example107 : Label2, Feature[7.3 2.9 6.3 1.8]
# Example108 : Label2, Feature[6.7 2.5 5.8 1.8]
# Example109 : Label2, Feature[7.2 3.6 6.1 2.5]
# Example110 : Label2, Feature[6.5 3.2 5.1 2. ]
# Example111 : Label2, Feature[6.4 2.7 5.3 1.9]
# Example112 : Label2, Feature[6.8 3.  5.5 2.1]
# Example113 : Label2, Feature[5.7 2.5 5.  2. ]
# Example114 : Label2, Feature[5.8 2.8 5.1 2.4]
# Example115 : Label2, Feature[6.4 3.2 5.3 2.3]
# Example116 : Label2, Feature[6.5 3.  5.5 1.8]
# Example117 : Label2, Feature[7.7 3.8 6.7 2.2]
# Example118 : Label2, Feature[7.7 2.6 6.9 2.3]
# Example119 : Label2, Feature[6.  2.2 5.  1.5]
# Example120 : Label2, Feature[6.9 3.2 5.7 2.3]
# Example121 : Label2, Feature[5.6 2.8 4.9 2. ]
# Example122 : Label2, Feature[7.7 2.8 6.7 2. ]
# Example123 : Label2, Feature[6.3 2.7 4.9 1.8]
# Example124 : Label2, Feature[6.7 3.3 5.7 2.1]
# Example125 : Label2, Feature[7.2 3.2 6.  1.8]
# Example126 : Label2, Feature[6.2 2.8 4.8 1.8]
# Example127 : Label2, Feature[6.1 3.  4.9 1.8]
# Example128 : Label2, Feature[6.4 2.8 5.6 2.1]
# Example129 : Label2, Feature[7.2 3.  5.8 1.6]
# Example130 : Label2, Feature[7.4 2.8 6.1 1.9]
# Example131 : Label2, Feature[7.9 3.8 6.4 2. ]
# Example132 : Label2, Feature[6.4 2.8 5.6 2.2]
# Example133 : Label2, Feature[6.3 2.8 5.1 1.5]
# Example134 : Label2, Feature[6.1 2.6 5.6 1.4]
# Example135 : Label2, Feature[7.7 3.  6.1 2.3]
# Example136 : Label2, Feature[6.3 3.4 5.6 2.4]
# Example137 : Label2, Feature[6.4 3.1 5.5 1.8]
# Example138 : Label2, Feature[6.  3.  4.8 1.8]
# Example139 : Label2, Feature[6.9 3.1 5.4 2.1]
# Example140 : Label2, Feature[6.7 3.1 5.6 2.4]
# Example141 : Label2, Feature[6.9 3.1 5.1 2.3]
# Example142 : Label2, Feature[5.8 2.7 5.1 1.9]
# Example143 : Label2, Feature[6.8 3.2 5.9 2.3]
# Example144 : Label2, Feature[6.7 3.3 5.7 2.5]
# Example145 : Label2, Feature[6.7 3.  5.2 2.3]
# Example146 : Label2, Feature[6.3 2.5 5.  1.9]
# Example147 : Label2, Feature[6.5 3.  5.2 2. ]
# Example148 : Label2, Feature[6.2 3.4 5.4 2.3]
# Example149 : Label2, Feature[5.9 3.  5.1 1.8]

# %% [markdown]
# ### Training a Classifier

# %% [markdown]
# First i am gonna divide the training data in to 2 parts:
# 1. The data that will be used to train the classifier
# 2. the data that will be used to test the classifier

# %%
import numpy as np

# %% [markdown]
# #### Training data
# * the Setosa is at the index 0
# * the versicolor is at the index 50
# * the Virginica is at the index 100

# %%
test_idx = [0,50,100]
train_target = np.delete(iris.target, test_idx)
train_data = np.delete(iris.data, test_idx, axis=0)

# %% [markdown]
# #### Testing Data

# %%
Test_target = iris.target[test_idx]
Test_data = iris.data[test_idx]

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Predicting the label for new flower

# %%
print(f'These are the test target for the clf to predict:{Test_target}')
print(clf.predict(Test_data))
# Out:
# These are the test target for the clf to predict:[0 1 2]
# [0 1 2]

# %% [markdown]
# ### Visualizing the Tree

# %%
from io import StringIO
import pydotplus
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Train Decision Tree
clf = DecisionTreeClassifier()
clf.fit(X, y)

# Create the decision tree visualization
dot_data = StringIO()
tree.export_graphviz(clf, 
                     out_file=dot_data,
                     feature_names=iris.feature_names,
                     class_names=iris.target_names,
                     filled=True, 
                     rounded=False,
                     impurity=False)

# Generate the graph
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# Save as a PDF file
graph.write_pdf("decision_tree.pdf")

print("PDF generated successfully as decision_tree.pdf")
